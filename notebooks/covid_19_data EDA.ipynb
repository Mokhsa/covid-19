# %% [markdown]
# # Project - COVID-19 Analysis [EDA & Visualization]

# %% [markdown]
# - You can find the full project at: https://ourworldindata.org/coronavirus
# - Daily-updated dataset link: https://covid.ourworldindata.org/data/owid-covid-data.csv
# - We'll be exploring the dataset from: https://covid.ourworldindata.org
# - Dashboard Example: https://coronavirus.jhu.edu/map.html

# %% [markdown]
# ### Importing libraries & data

# %%
import numpy as np
import pandas as pd 
import matplotlib .pyplot as plt 
import seaborn as sns
# %matplotlib inline
sns.set()
import plotly.express as px

# %%
df=pd.read_csv(r'https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 358641      ZWE    Africa  Zimbabwe  2023-11-18     265890.0        0.0
# 358642      ZWE    Africa  Zimbabwe  2023-11-19     265890.0        0.0
# 358643      ZWE    Africa  Zimbabwe  2023-11-20     265890.0        0.0
# 358644      ZWE    Africa  Zimbabwe  2023-11-21     265890.0        0.0
# 358645      ZWE    Africa  Zimbabwe  2023-11-22     265890.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 358641                 0.0        5725.0         0.0                  0.0
# 358642                 0.0        5725.0         0.0                  0.0
# 358643                 0.0        5725.0         0.0                  0.0
# 358644                 0.0        5725.0         0.0                  0.0
# 358645                 0.0        5725.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 358641  ...          30.7                  36.791                         1.7
# 358642  ...          30.7                  36.791                         1.7
# 358643  ...          30.7                  36.791                         1.7
# 358644  ...          30.7                  36.791                         1.7
# 358645  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 358641            61.49                    0.571  16320539.0
# 358642            61.49                    0.571  16320539.0
# 358643            61.49                    0.571  16320539.0
# 358644            61.49                    0.571  16320539.0
# 358645            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 358641                                   NaN                          NaN
# 358642                                   NaN                          NaN
# 358643                                   NaN                          NaN
# 358644                                   NaN                          NaN
# 358645                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 358641               NaN                                      NaN
# 358642               NaN                                      NaN
# 358643               NaN                                      NaN
# 358644               NaN                                      NaN
# 358645               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
df.shape
# Out:
# (358646, 67)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358646 entries, 0 to 358645
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    358646 non-null  object
#  1   continent                                   341606 non-null  object
#  2   location                                    358646 non-null  object
#  3   date                                        358646 non-null  object
#  4   total_cases                                 320628 non-null  float64
#  5   new_cases                                   349032 non-null  float64
#  6   new_cases_smoothed                          347773 non-null  float64
#  7   total_deaths                                299086 non-null  float64
#  8   new_deaths                                  349089 non-null  float64
#  9   new_deaths_smoothed                         347859 non-null  float64
#  10  total_cases_per_million                     320628 non-null  float64
#  11  new_cases_per_million                       349032 non-null  float64
#  12  new_cases_smoothed_per_million              347773 non-null  float64
#  13  total_deaths_per_million                    299086 non-null  float64
#  14  new_deaths_per_million                      349089 non-null  float64
#  15  new_deaths_smoothed_per_million             347859 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                37804 non-null   float64
#  18  icu_patients_per_million                    37804 non-null   float64
#  19  hosp_patients                               39178 non-null   float64
#  20  hosp_patients_per_million                   39178 non-null   float64
#  21  weekly_icu_admissions                       10295 non-null   float64
#  22  weekly_icu_admissions_per_million           10295 non-null   float64
#  23  weekly_hosp_admissions                      23453 non-null   float64
#  24  weekly_hosp_admissions_per_million          23453 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          79964 non-null   float64
#  35  people_vaccinated                           76534 non-null   float64
#  36  people_fully_vaccinated                     73223 non-null   float64
#  37  total_boosters                              48175 non-null   float64
#  38  new_vaccinations                            65944 non-null   float64
#  39  new_vaccinations_smoothed                   183044 non-null  float64
#  40  total_vaccinations_per_hundred              79964 non-null   float64
#  41  people_vaccinated_per_hundred               76534 non-null   float64
#  42  people_fully_vaccinated_per_hundred         73223 non-null   float64
#  43  total_boosters_per_hundred                  48175 non-null   float64
#  44  new_vaccinations_smoothed_per_million       183044 non-null  float64
#  45  new_people_vaccinated_smoothed              182800 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  182800 non-null  float64
#  47  stringency_index                            197651 non-null  float64
#  48  population_density                          304568 non-null  float64
#  49  median_age                                  283197 non-null  float64
#  50  aged_65_older                               273328 non-null  float64
#  51  aged_70_older                               280357 non-null  float64
#  52  gdp_per_capita                              277588 non-null  float64
#  53  extreme_poverty                             178924 non-null  float64
#  54  cardiovasc_death_rate                       278252 non-null  float64
#  55  diabetes_prevalence                         292413 non-null  float64
#  56  female_smokers                              208744 non-null  float64
#  57  male_smokers                                205904 non-null  float64
#  58  handwashing_facilities                      136322 non-null  float64
#  59  hospital_beds_per_thousand                  245664 non-null  float64
#  60  life_expectancy                             330057 non-null  float64
#  61  human_development_index                     269693 non-null  float64
#  62  population                                  358646 non-null  float64
#  63  excess_mortality_cumulative_absolute        12211 non-null   float64
#  64  excess_mortality_cumulative                 12211 non-null   float64
#  65  excess_mortality                            12211 non-null   float64
#  66  excess_mortality_cumulative_per_million     12211 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 183.3+ MB

# %%
df.describe().T
# Out:
#                                             count          mean           std  \
# total_cases                              320628.0  6.862419e+06  4.155251e+07
# new_cases                                349032.0  9.375506e+03  1.089256e+05
# new_cases_smoothed                       347773.0  9.409256e+03  9.331850e+04
# total_deaths                             299086.0  8.695437e+04  4.439683e+05
# new_deaths                               349089.0  8.351554e+01  6.290777e+02
# ...                                           ...           ...           ...
# population                               358646.0  1.282212e+08  6.599107e+08
# excess_mortality_cumulative_absolute      12211.0  5.312168e+04  1.494480e+05
# excess_mortality_cumulative               12211.0  9.760347e+00  1.229389e+01
# excess_mortality                          12211.0  1.133770e+01  2.516691e+01
# excess_mortality_cumulative_per_million   12211.0  1.675398e+03  1.941471e+03
#
#                                                 min            25%  \
# total_cases                                  1.0000    8355.000000
# new_cases                                    0.0000       0.000000
# new_cases_smoothed                           0.0000       0.143000
# total_deaths                                 1.0000     129.000000
# new_deaths                                   0.0000       0.000000
# ...                                             ...            ...
# population                                  47.0000  449002.000000
# excess_mortality_cumulative_absolute    -37726.0980     121.649992
# excess_mortality_cumulative                -44.2300       1.430000
# excess_mortality                           -95.9200      -1.590000
# excess_mortality_cumulative_per_million  -2752.9248      73.764453
#
#                                                   50%           75%  \
# total_cases                              7.271900e+04  7.844830e+05
# new_cases                                1.000000e+00  2.440000e+02
# new_cases_smoothed                       2.285700e+01  4.737140e+02
# total_deaths                             1.349000e+03  1.201900e+04
# new_deaths                               0.000000e+00  2.000000e+00
# ...                                               ...           ...
# population                               5.882259e+06  2.830170e+07
# excess_mortality_cumulative_absolute     5.968999e+03  3.770731e+04
# excess_mortality_cumulative              8.100000e+00  1.538000e+01
# excess_mortality                         5.720000e+00  1.630000e+01
# excess_mortality_cumulative_per_million  1.115956e+03  2.746704e+03
#
#                                                   max
# total_cases                              7.721658e+08
# new_cases                                8.401963e+06
# new_cases_smoothed                       6.402036e+06
# total_deaths                             6.981250e+06
# new_deaths                               5.788900e+04
# ...                                               ...
# population                               7.975105e+09
# excess_mortality_cumulative_absolute     1.289776e+06
# excess_mortality_cumulative              7.662000e+01
# excess_mortality                         3.776300e+02
# excess_mortality_cumulative_per_million  1.029292e+04
#
# [62 rows x 8 columns]

# %%
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# population                                 float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# ### EXPlORING WORLD DATA

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'High income', 'Honduras',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica',
#        'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low income', 'Lower middle income', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mayotte', 'Mexico', 'Micronesia (country)', 'Moldova', 'Monaco',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'North America', 'North Korea', 'North Macedonia',
#        'Northern Cyprus', 'Northern Ireland', 'Northern Mariana Islands',
#        'Norway', 'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Reunion', 'Romania', 'Russia', 'Rwanda', 'Saint Barthelemy',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Martin (French part)', 'Saint Pierre and Miquelon',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wales', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df['location'].nunique()
# Out:
# 255

# %%
df_world=df[df['location']=='World']
df_world.reset_index()
# Out:
#        index  iso_code continent location        date  total_cases  new_cases  \
# 0     352966  OWID_WRL       NaN    World  2020-01-03          NaN        0.0
# 1     352967  OWID_WRL       NaN    World  2020-01-04          3.0        3.0
# 2     352968  OWID_WRL       NaN    World  2020-01-05          2.0        0.0
# 3     352969  OWID_WRL       NaN    World  2020-01-06          5.0        3.0
# 4     352970  OWID_WRL       NaN    World  2020-01-07          5.0        0.0
# ...      ...       ...       ...      ...         ...          ...        ...
# 1415  354381  OWID_WRL       NaN    World  2023-11-18  772164882.0     2748.0
# 1416  354382  OWID_WRL       NaN    World  2023-11-19  772165753.0      871.0
# 1417  354383  OWID_WRL       NaN    World  2023-11-20  772165753.0        0.0
# 1418  354384  OWID_WRL       NaN    World  2023-11-21  772165753.0        0.0
# 1419  354385  OWID_WRL       NaN    World  2023-11-22  772165753.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  ...  male_smokers  \
# 0                    NaN           NaN         0.0  ...        34.635
# 1                    NaN           NaN         0.0  ...        34.635
# 2                    NaN           3.0         3.0  ...        34.635
# 3                    NaN           3.0         0.0  ...        34.635
# 4                    NaN           3.0         0.0  ...        34.635
# ...                  ...           ...         ...  ...           ...
# 1415           19522.429     6981218.0        15.0  ...        34.635
# 1416           18297.429     6981250.0        32.0  ...        34.635
# 1417           12107.143     6981250.0         0.0  ...        34.635
# 1418            4359.000     6981250.0         0.0  ...        34.635
# 1419            2467.286     6981250.0         0.0  ...        34.635
#
#       handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      60.13                       2.705            72.58
# 1                      60.13                       2.705            72.58
# 2                      60.13                       2.705            72.58
# 3                      60.13                       2.705            72.58
# 4                      60.13                       2.705            72.58
# ...                      ...                         ...              ...
# 1415                   60.13                       2.705            72.58
# 1416                   60.13                       2.705            72.58
# 1417                   60.13                       2.705            72.58
# 1418                   60.13                       2.705            72.58
# 1419                   60.13                       2.705            72.58
#
#       human_development_index    population  \
# 0                       0.737  7.975105e+09
# 1                       0.737  7.975105e+09
# 2                       0.737  7.975105e+09
# 3                       0.737  7.975105e+09
# 4                       0.737  7.975105e+09
# ...                       ...           ...
# 1415                    0.737  7.975105e+09
# 1416                    0.737  7.975105e+09
# 1417                    0.737  7.975105e+09
# 1418                    0.737  7.975105e+09
# 1419                    0.737  7.975105e+09
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 1415                                   NaN                          NaN
# 1416                                   NaN                          NaN
# 1417                                   NaN                          NaN
# 1418                                   NaN                          NaN
# 1419                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 1415               NaN                                      NaN
# 1416               NaN                                      NaN
# 1417               NaN                                      NaN
# 1418               NaN                                      NaN
# 1419               NaN                                      NaN
#
# [1420 rows x 68 columns]

# %% [markdown]
# The date of the maximum number of the deaths all over the world ?

# %%
df_world .head()
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 352966  OWID_WRL       NaN    World  2020-01-03          NaN        0.0
# 352967  OWID_WRL       NaN    World  2020-01-04          3.0        3.0
# 352968  OWID_WRL       NaN    World  2020-01-05          2.0        0.0
# 352969  OWID_WRL       NaN    World  2020-01-06          5.0        3.0
# 352970  OWID_WRL       NaN    World  2020-01-07          5.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 352966                 NaN           NaN         0.0                  NaN
# 352967                 NaN           NaN         0.0                  NaN
# 352968                 NaN           3.0         3.0                  NaN
# 352969                 NaN           3.0         0.0                  NaN
# 352970                 NaN           3.0         0.0                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 352966  ...        34.635                   60.13                       2.705
# 352967  ...        34.635                   60.13                       2.705
# 352968  ...        34.635                   60.13                       2.705
# 352969  ...        34.635                   60.13                       2.705
# 352970  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 352966            72.58                    0.737  7.975105e+09
# 352967            72.58                    0.737  7.975105e+09
# 352968            72.58                    0.737  7.975105e+09
# 352969            72.58                    0.737  7.975105e+09
# 352970            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 352966                                   NaN                          NaN
# 352967                                   NaN                          NaN
# 352968                                   NaN                          NaN
# 352969                                   NaN                          NaN
# 352970                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 352966               NaN                                      NaN
# 352967               NaN                                      NaN
# 352968               NaN                                      NaN
# 352969               NaN                                      NaN
# 352970               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df_world[df_world['new_deaths']==df_world['new_deaths'].max()]
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 354091  OWID_WRL       NaN    World  2023-02-01  752663406.0   176142.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 354091          208955.857     6839545.0     57889.0             9392.429
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 354091  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 354091            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 354091                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 354091               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_world[df_world['new_deaths']==df_world['new_deaths'].max()]['date']
# Out:
# 354091    2023-02-01
# Name: date, dtype: object

# %%
px.line(df_world,y='new_deaths',x='date')

# %%
df[(df['date']=='2023-02-01')&(df['location']=='China')]
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 63607      CHN      Asia    China  2023-02-01   98527660.0    55271.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 63607           24618.286      113926.0     44047.0             6292.429  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 63607          48.4                     NaN                        4.34
#
#        life_expectancy  human_development_index    population  \
# 63607            76.91                    0.761  1.425887e+09
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 63607                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 63607               NaN                                      NaN
#
# [1 rows x 67 columns]

# %% [markdown]
# ### calculating the percentage of confirmed cases regarding the world population

# %%
df_world['total_cases'].max()
# Out:
# 772165753.0

# %%
df_world['population'].max()
# Out:
# 7975105024.0

# %%
df_world_ratio=df_world['total_cases'].max() / df_world['population'].max()
df_world_ratio
# Out:
# 0.09682201684821348

# %%
print('{:.2f}'.format(df_world_ratio))
# Out:
# 0.10
